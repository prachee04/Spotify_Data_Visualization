# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import plotly
import plotly.express as px

#matplotlib inline

# %%
df = pd.read_csv("/content/spotify_dataset.csv", encoding='latin-1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d47f6efe1b1> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/spotify_dataset.csv", encoding='latin-1')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a74c58233b9e> in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
#number of times charted by artist

df_numbercharted=df.groupby('Artist').sum().sort_values('Number of Times Charted', ascending=False) #descending order sort
df_numbercharted=df_numbercharted.reset_index()
df_numbercharted
# Out:
# <ipython-input-6-9fb098dce46d>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_numbercharted=df.groupby('Artist').sum().sort_values('Number of Times Charted', ascending=False)
#                     Artist  Index  Highest Charting Position  \
# 0            Billie Eilish  13908                       1136
# 1               Juice WRLD  25342                       1755
# 2             Harry Styles   1990                        139
# 3               Ed Sheeran   4440                        657
# 4                Pop Smoke  17702                       2420
# ..                     ...    ...                        ...
# 711          KALIM, Ufo361   1143                        183
# 712  Kane Brown, blackbear    231                        187
# 713                Kehlani   1191                        177
# 714     Kygo, Donna Summer    897                        194
# 715               Kontra K   1033                        129
#
#      Number of Times Charted
# 0                        432
# 1                        431
# 2                        364
# 3                        314
# 4                        308
# ..                       ...
# 711                        1
# 712                        1
# 713                        1
# 714                        1
# 715                        1
#
# [716 rows x 4 columns]

# %%
px.bar(x='Artist', y='Number of Times Charted', data_frame=df_numbercharted.head(7), title="Top 7 Artists with Highes Number of Times Charted")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f58f320a-7863-4bb0-8557-67ba10222db3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f58f320a-7863-4bb0-8557-67ba10222db3")) {                    Plotly.newPlot(                        "f58f320a-7863-4bb0-8557-67ba10222db3",                        [{"alignmentgroup":"True","hovertemplate":"Artist=%{x}\u003cbr\u003eNumber of Times Charted=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Billie Eilish","Juice WRLD","Harry Styles","Ed Sheeran","Pop Smoke","Ariana Grande","Dua Lipa"],"xaxis":"x","y":[432,431,364,314,308,288,281],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type ...

# %%
#check out correaltion
#clean data first

df=df.fillna('')
df=df.replace(' ', '') #missing data replacement
df['Streams']=df['Streams'].str.replace(',','') #to remove commas in numbers (1,00,000 = 100000)

#convet all numeric columns to numeric

df[['Highest Charting Position', 'Number of Times Charted', 'Streams', 'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
       ]] = df[['Highest Charting Position', 'Number of Times Charted', 'Streams','Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
       ]].apply(pd.to_numeric)

# %%
#let's also separate year from the column "Release date" to be able to analyze its correlations

df['Release Year'] = pd.DatetimeIndex(df['Release Date']).year

# %%
f,ax = plt.subplots(figsize=(14,10))
sns.heatmap(df.corr(),annot = True,fmt = ".1f",ax = ax)
plt.show()
# Out:
# <ipython-input-10-090ddf2c37a7>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
#dancealibility

px.line(x='Release Year', y='Danceability', data_frame=df, title="Danceability over the course of the Year")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94adbd00-0af0-4eb2-8747-2fad25160220" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94adbd00-0af0-4eb2-8747-2fad25160220")) {                    Plotly.newPlot(                        "94adbd00-0af0-4eb2-8747-2fad25160220",                        [{"hovertemplate":"Release Year=%{x}\u003cbr\u003eDanceability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[2017.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2019.0,null,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2020.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2018.0,2013.0,2021.0,2019.0,2021.0,2021.0,2021.0,2021.0,2017.0,2021.0,2020.0,2021.0,2021.0,2019.0,2020.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2019.0,2021.0,2019.0,2021.0,2020.0,2019.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2019.0,2020.0,2021.0,2021.0,2017.0,2020.0,2010.0,2020.0,2021.0,2021.0,2021.0,2018.0,2018.0,2019.0,2019.0,2021.0,2021.0,2017.0,2019.0,2021.0,2017.0,2021.0,2020.0,2020.0,2020.0,2020.0,2014.0,2014.0,1991.0,2021.0,2015.0,2021.0,2021.0,2021.0,2013.0,2021.0,2014.0,2021.0,2021.0,2021.0,2020.0,2021.0,1975.0,2020.0,2020.0,2021.0,2021.0,2021.0,2018.0,2021.0,2021.0,2014.0,2000.0,2021.0,2021.0,2013.0,2021.0,2021.0,2020.0,2014.0,2021.0,2021.0,2018.0,2021.0,null,2021.0,2021.0,2020.0,2021.0,2020.0,2004.0,1983.0,1977.0,2016.0,2021.0,2021.0,2021.0,2020.0,2021.0,1980.0,2016.0,2019.0,2021.0,2021.0,2021.0,2013.0,2020.0,2019.0,2021.0,2015.0,2020.0,2021.0,2021.0,2019.0,2020.0,2021.0,2019.0,2021.0,2021.0,2021.0,2000.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2019.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2016.0,1995.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2020.0,2011.0,2020.0,2021.0,2021.0,2013.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2020.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2017.0,2021.0,2019.0,2021.0,2012.0,2021.0,2020.0,2010.0,2019.0,2020.0,2020.0,2021.0,2021.0,2000.0,2014.0,2018.0,2017.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2020.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2019.0,2021.0,2021.0,2021.0,2021.0,2020.0,2018.0,2021.0,2019.0,2021.0,2020.0,2020.0,2011.0,2020.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2012.0,2019.0,2020.0,2020.0,2021.0,2020.0,2005.0,2019.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2020.0,2020.0,2021.0,2020.0,2021.0,2021.0,2021.0,2020.0,2019.0,2021.0,2020.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2020.0,2021.0,2021.0,2021.0,2020.0,2020.0,2016.0,2020.0,2020.0,2018.0,2021.0,2020.0,2012.0,2021.0,2015.0,2021.0,2021.0,2021.0,2020.0,2021.0,2020.0,2013.0,2021.0,2019.0,2021.0,2021.0,2007.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,1998.0,2021.0,2021.0,2021.0,2021.0,2020.0,2021.0,2021.0,2021.0,2021.0,2021.0,2021.0,2020.0,2019.0,2020.0,2021.0,2020.0,2008.0,202 ...

# %%
#Number of Times Charted' correlates with years

dfyear = df.groupby('Release Year').sum().sort_values('Number of Times Charted', ascending=False) #descending order sorting
dfyear=dfyear.reset_index()


px.bar(x='Release Year', y='Number of Times Charted', data_frame=dfyear.head(7))
# Out:
# <ipython-input-12-86e00075c454>:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac9d2dbc-03bc-4354-926f-93d51af0d7c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac9d2dbc-03bc-4354-926f-93d51af0d7c7")) {                    Plotly.newPlot(                        "ac9d2dbc-03bc-4354-926f-93d51af0d7c7",                        [{"alignmentgroup":"True","hovertemplate":"Release Year=%{x}\u003cbr\u003eNumber of Times Charted=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2020.0,2019.0,2021.0,2018.0,2017.0,2013.0,2016.0],"xaxis":"x","y":[6966,3696,2890,1116,409,236,207],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %%
artistbypop = df.groupby('Artist').sum().sort_values('Popularity' ,ascending=False)[:20]
artistbypop=artistbypop.reset_index()


px.bar(x='Artist', y='Popularity', data_frame=artistbypop)
# Out:
# <ipython-input-13-0aa124ef263e>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5775e745-a4ab-41a0-852f-877d33793112" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5775e745-a4ab-41a0-852f-877d33793112")) {                    Plotly.newPlot(                        "5775e745-a4ab-41a0-852f-877d33793112",                        [{"alignmentgroup":"True","hovertemplate":"Artist=%{x}\u003cbr\u003ePopularity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Taylor Swift","Juice WRLD","BTS","Bad Bunny","Justin Bieber","Lil Uzi Vert","Pop Smoke","The Weeknd","Eminem","Drake","Ariana Grande","Doja Cat","J. Cole","Tyler, The Creator","Olivia Rodrigo","DaBaby","Selena Gomez","Dua Lipa","Polo G","Lady Gaga"],"xaxis":"x","y":[3558.0,2210.0,2181.0,2062.0,2005.0,2001.0,1970.0,1549.0,1448.0,1337.0,1284.0,1283.0,1196.0,1073.0,1071.0,995.0,970.0,955.0,849.0,809.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"sca ...

# %%
#most popular genres

df['Genre']=df['Genre'].astype(str) #converts to strings
df["Genre"][df["Genre"] == "[]"] = np.nan #missing value treatment by adding NaN
df["Genre"] = df["Genre"].fillna(0)

#here we get rid of useless symbols to be able to separate genres
df.Genre=df.Genre.str.replace("[", "")
df.Genre=df.Genre.str.replace("]", "")
df.Genre=df.Genre.str.replace("'", "")

#now we devide genre strings by comma

df["Genre"] = df["Genre"].str.split(",")

df=df.explode('Genre') #expanding rows for each column

df
# Out:
# <ipython-input-15-0e4c5fef0947>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-15-0e4c5fef0947>:7: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-15-0e4c5fef0947>:8: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# ...     ...                        ...                      ...
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name   Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48633449
# 0      2021-07-23--2021-07-30                             Beggin'  48633449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47248719
# 2      2021-06-25--2021-07-02                            good 4 u  40162559
# 3      2021-07-02--2021-07-09                          Bad Habits  37799456
# ...                       ...                                 ...       ...
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4620876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4607385
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4607385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4595450
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4595450
#
#                                Artist Artist Followers  \
# 0                           MÃ¥neskin          3377762
# 0                           MÃ¥neskin          3377762
# 1                       The Kid LAROI          2230022
# 2                      Olivia Rodrigo          6266514
# 3                          Ed Sheeran         83293380
# ...                               ...              ...
# 1553                   Camila Cabello         22698747
# 1554  DadÃ¡ BoladÃ£o, Tati Zaqui, OIK           208630
# 1554  DadÃ¡ BoladÃ£o, Tati Zaqui, OIK           208630
# 1555                     Taylor Swift         42227614
# 1555                     Taylor Swift         42227614
#
#                      Song ID                Genre  ... Energy Loudness  \
# 0     3Wrjm47oTz2sjIgck11l5e  indie rock italiano  ...  0.800   -4.808
# 0     3Wrjm47oTz2sjIgck11l5e          italian pop  ...  0.800   -4.808
# 1     5HCyWlXZPP0y6Gqq8TgA20   australian hip hop  ...  0.764   -5.484
# 2     4ZtFanR9U6ndgddUvNcjcG                  pop  ...  0.664   -5.044
# 3     6PQ88X9TkUIAUIZJHW2upE                  pop  ...  0.897   -3.712
# ...                      ...                  ...  ...    ...      ...
# 1553  1rfofaqEpACxVEHIZBJe6W        post-teen pop  ...  0.523   -4.333
# 1554  5F8ffc8KWKNawllr5WsW0r           brega funk  ...  0.550   -7.026
# 1554  5F8ffc8KWKNawllr5WsW0r         funk carioca  ...  0.550   -7.026
# 1555  3i9UVldZOE0aD0JnyfAZZ0                  pop  ...  0.603   -7.176
# 1555  3i9UVldZOE0aD0JnyfAZZ0        post-teen pop  ...  0.603   -7.176
#
#       Speechiness  Acousticness  Liveness    Tempo  Duration (ms)  Valence  \
# 0          0.0504        0.1270    0.3590  134.002       211560.0    0.589
# 0          0.0504        0.1270    0.3590  134.002       211560.0    0.589
# 1          0.0483        0.0383    0.1030  169.928       141806.0    0.478
# 2          0.1540        0.3350    0.0849  166.928       178147.0    0.688
# 3          0.0348        0.0469    0.3640  126.026       231041.0    0.591
# ...           ...           ...       ...      ...            ...      ...
# 1553       0.0300        0.1840    0.1320  104.988       217307.0    0.394
# 1554       0.0587        0.2490    0.1820  154.064       152784.0    0.881
# 1554       0.0587        0.2490    0.1820  154.064       152784.0    0.881
# 1555       0.0640        0.4330    0.0862  205.272       221307.0    0.422
# 1555       0.0640        0.4330    0.0862  205.272       221307.0    0.422
#
#       Chord  Release Year
# 0         B        2017.0
# 0         B        2017.0
# 1     C#/Db        2021.0
# 2         A        2021.0
# 3         B        2021.0
# ...     ...           ...
# 1553      D        2018.0
# 1554      F        2019.0
# 1554      F        2019.0
# 1555      G        2019.0
# 1555      G        2019.0
#
# [4665 rows x 24 columns]

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.subplots()
df.Genre.value_counts()[:30].plot(ax=ax, kind = "pie") #counts the frequencey and plots the pie chart
ax.set_ylabel("")
ax.set_title("Top 30 most popular genres")
plt.show()
